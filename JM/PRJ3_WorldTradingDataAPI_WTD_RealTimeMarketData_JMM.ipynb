# %%
# WORLD TRADING DATA (WTD) - INTRODUCTION:
# https://www.worldtradingdata.com/documentation?python#introduction

# Register for a World Trading Data API Key:
# https://www.worldtradingdata.com/register

# World Trading Data database of supported stocks and indices:
# https://www.worldtradingdata.com/search

# World Trading Data database of supported forex pairs:
# https://www.worldtradingdata.com/search/forex

# %%
# WTD - AUTHENTICATION:
# Each API request is authenticated with your own personal API token. Include your API token in each request by passing
# it as a query parameter in each request.

#my_api_token = 'YOUR_API_TOKEN'
#my_api_token = '******* YOUR_API_TOKEN *******'

# Import API Keys:
from api_keys import world_trading_data_api_token

# %%
# WTD - REAL TIME MARKET DATA:

# HTTP Request:
# GET https://api.worldtradingdata.com/api/v1/stock

# Query Parameters:
# The endpoint takes up to 5 query parameters: symbol, api_token, sort_order, sort_by and output.
# The symbol parameter allows you to request real time data.
# The output=csv parameter will return the data as a CSV format but by default will return JSON.
# The api_token is used to verify each request.

# Required Parameters: symbol; api_token
# Example: symbol=SNAP, TWTR, VOD.L; my_api_token

# Optional Parameters: sort_order, sort_by, output
# Example: sort_order=desc/asc, sort_by=name/symbol/list_order, output=json/csv

# %%
# WTD - REAL TIME MARKET DATA:

# Full History:
# World Trading Data's real time data endpoint returns the nearest trading data for stocks and indexes worldwide.

# Top 30 largest US financial companies 2020:
# https://disfold.com/top-us-financial-companies/

# Top 25 (of the above 30) Financial Stocks Available from the World Trading Data API:
#1. Berkshire Hathaway - 'BRK.B'
#2. JPMorgan Chase - 'JPM'
#3. Bank of America - 'BAC'
#4. Wells Fargo - 'WFC'
#5. Citigroup - 'C'
#6. American Express - 'AXP'
#7. Morgan Stanley - 'MS'
#8. BlackRock - 'BLK'
#9. U.S. Bancorp - 'USB'
#10. Goldman Sachs - 'GS'
#11. Truist Financial - 'TFC'
#12. Chubb - 'CB'
#13. S&P Global - 'SPGI'
#14. PNC Financial Services - 'PNC'
#15. Charles Schwab - 'SCHW'
#16. Marsh & McLennan - 'MMC'
#17. Aon - 'AON'
#18. Intercontinental Exchange - 'ICE'
#19. Moody’s - 'MCO'
#20. Progressive - 'PGR'
#21. MetLife - 'MET'
#22. American International Group - 'AIG'
#23. Capital One - 'COF'
#24. The Bank of New York Mellon - 'BK'
#25. Allstate Corp - 'ALL'

# %%
# WTD - REAL TIME MARKET DATA - SECTION #1:

# Stock and Index Real Time:
# World Trading Data's real time data endpoint returns the nearest trading data for stocks and indexes worldwide.
# The endpoint allows up to 500 stocks or indexes to be returned with each request.

# 25 Financial Stocks Available from the World Trading Data API:
# Set #1:    'BRK.B,JPM,BAC,WFC,C'
# Set #2:    'AXP,MS,BLK,USB,GS'
# Set #3:    'TFC,CB,SPGI,PNC,SCHW'
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API NOTE:
# Currently using the free version of the World Trading Data API.
# (maximum of 5 ticker symbols per request)
# Pricing: https://www.worldtradingdata.com/pricing

# WTD - API - Real Time Market Data - Dependencies & Setup:
import requests
import json
import csv
import pandas as pd

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #1: 'symbol': 'BRK.B,JPM,BAC,WFC,C',
params = {'symbol': 'BRK.B,JPM,BAC,WFC,C',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - API Output, "stocks_response_api" - Raw & Un-modified:
stocks_response_api
# Out:
# <Response [200]>

# %%
# WTD - API Output, "stocks_response_api" - Data Type:
type(stocks_response_api)
# Out:
# requests.models.Response

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'BAC',
#    'name': 'Bank of America Corporation',
#    'currency': 'USD',
#    'price': '22.04',
#    'price_open': '21.65',
#    'day_high': '22.35',
#    'day_low': '21.27',
#    '52_week_high': '35.72',
#    '52_week_low': '17.95',
#    'day_change': '0.44',
#    'change_pct': '2.04',
#    'close_yesterday': '21.60',
#    'market_cap': '192293928960',
#    'volume': '80323108',
#    'volume_avg': '139202966',
#    'shares': '8724769792',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '8.01',
#    'eps': '2.75'},
#   {'symbol': 'BRK.B',
#    'name': 'Berkshire Hathaway Inc.',
#    'currency': 'USD',
#    'price': '183.18',
#    'price_open': '180.04',
#    'day_high': '184.11',
#    'day_low': '178.00',
#    '52_week_high': '231.61',
#    '52_week_low': '159.50',
#    'day_change': '3.52',
#    'change_pct': '1.96',
#    'close_yesterday': '179.66',
#    'market_cap': '444345221120',
#    'volume': '7363917',
#    'volume_avg': '14005383',
#    'shares': '1382349952',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '0.00',
#    'eps': '49828.45'},
#   {'symbol': 'C',
#    'name': 'Citigroup Inc.',
#    'currency': 'USD',
#    'price': '44.08',
#    'price_open': '44.05',
#    'day_high': '44.26',
#    'day_low': '41.58',
#    '52_week_high': '83.11',
#    '52_week_low': '32.00',
#    'day_change': '0.28',
#    'change_pct': '0.64',
#    'close_yesterday': '43.80',
#    'market_cap': '92489105408',
#    'volume': '27147868',
#    'volume_avg': '33415683',
#    'shares': '2098210048',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '5.49',
#    'eps': '8.04'},
#   {'symbol': 'JPM',
#    'name': 'JPMorgan Chase & Co.',
#    'currency': 'USD',
#    'price': '93.50',
#    'price_open': '90.65',
#    'day_high': '94.09',
#    'day_low': '89.30',
#    '52_week_high': '141.10',
#    '52_week_low': '76.91',
#    'day_change': '2.37',
#    'change_pct': '2.60',
#    'close_yesterday': '91.13',
#    'market_cap': '287417106432',
#    'volume': '21582551',
#    'volume_avg': '32501400',
#    'shares': '3084000000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '8.72',
#    'eps': '10.72'},
#   {'symbol': 'WFC',
#    'name': 'Wells Fargo & Company',
#    'currency': 'USD',
#    'price': '29.92',
#    'price_open': '30.36',
#    'day_high': '30.48',
#    'day_low': '28.89',
#    '52_week_high': '54.75',
#    '52_week_low': '25.11',
#    'day_change': '-0.36',
#    'change_pct': '-1.19',
#    'close_yesterday': '30.28',
#    'market_cap': '122354851840',
#    'volume': '41153005',
#    'volume_avg': '51229066',
#    'shares': '4089400064',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '7.39',
#    'eps': '4.05'}]}

# %%
# WTD - API Output, "stocks_response_json" - Data Type:
type(stocks_response_json)
# Out:
# dict

# %%
# # ***NOTE: Not currently using this block of code!***
# # The JSON Dictionary API Output, "stocks_response_json", is provided "pre-sorted" in chronological order,
# # by date, from NEWEST to OLDEST.

# # Sort JSON Dictionary, "stocks_response_json", in chronological order, by date, from OLDEST to NEWEST:
# # (sorting JSON dictionary keys in ascending order)
# stocks_response_json_sorted = json.dumps(stocks_response_json, indent = 4, sort_keys = True)
# print(stocks_response_json_sorted)

# %%
# # WTD - JSON String (appears as a "pretty print" JSON Dictionary), "stocks_response_json_sorted" - Data Type:
# type(stocks_response_json_sorted)

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__BRKB_JPM_BAC_WFC_C__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_one = ['BRK.B', 'JPM', 'BAC', 'WFC', 'C']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_one:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Print the "stocks_response_json_list" to confirm it is currently FULL of data items:
print(stocks_response_json_list)
# Out:
# [['BAC', 'Bank of America Corporation', 'USD', '22.04', '21.65', '22.35', '21.27', '35.72', '17.95', '0.44', '2.04', '21.60', '192293928960', '80323108', '139202966', '8724769792', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-03-30 16:02:00', '8.01', '2.75'], ['BRK.B', 'Berkshire Hathaway Inc.', 'USD', '183.18', '180.04', '184.11', '178.00', '231.61', '159.50', '3.52', '1.96', '179.66', '444345221120', '7363917', '14005383', '1382349952', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-03-30 16:02:00', '0.00', '49828.45'], ['C', 'Citigroup Inc.', 'USD', '44.08', '44.05', '44.26', '41.58', '83.11', '32.00', '0.28', '0.64', '43.80', '92489105408', '27147868', '33415683', '2098210048', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-03-30 16:02:00', '5.49', '8.04'], ['JPM', 'JPMorgan Chase & Co.', 'USD', '93.50', '90.65', '94.09', '89.30', '141.10', '76.91', '2.37', '2.60', '91.13', '287417106432', '21582551', '32501400', '3084000000', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-03-30 16:02:00', '8.72', '10.72'], ['WFC', 'Wells Fargo & Company', 'USD', '29.92', '30.36', '30.48', '28.89', '54.75', '25.11', '-0.36', '-1.19', '30.28', '122354851840', '41153005', '51229066', '4089400064', 'New York Stock Exchange', 'NYSE', 'EDT', 'America/New_York', '-14400', '2020-03-30 16:02:00', '7.39', '4.05']]

# %%
# Create "stocks_response_json_list_one_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_one_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_one_df" DataFrame columns:
stocks_response_json_list_one_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_one_df
# Out:
#   symbol                         name currency   price price_open day_high  \
# 0    BAC  Bank of America Corporation      USD   22.04      21.65    22.35
# 1  BRK.B      Berkshire Hathaway Inc.      USD  183.18     180.04   184.11
# 2      C               Citigroup Inc.      USD   44.08      44.05    44.26
# 3    JPM         JPMorgan Chase & Co.      USD   93.50      90.65    94.09
# 4    WFC        Wells Fargo & Company      USD   29.92      30.36    30.48
#
#   day_low 52_week_high 52_week_low day_change  ... volume_avg      shares  \
# 0   21.27        35.72       17.95       0.44  ...  139202966  8724769792
# 1  178.00       231.61      159.50       3.52  ...   14005383  1382349952
# 2   41.58        83.11       32.00       0.28  ...   33415683  2098210048
# 3   89.30       141.10       76.91       2.37  ...   32501400  3084000000
# 4   28.89        54.75       25.11      -0.36  ...   51229066  4089400064
#
#        stock_exchange_long stock_exchange_short timezone     timezone_name  \
# 0  New York Stock Exchange                 NYSE      EDT  America/New_York
# 1  New York Stock Exchange                 NYSE      EDT  America/New_York
# 2  New York Stock Exchange                 NYSE      EDT  America/New_York
# 3  New York Stock Exchange                 NYSE      EDT  America/New_York
# 4  New York Stock Exchange                 NYSE      EDT  America/New_York
#
#   gmt_offset      last_trade_time    pe       eps
# 0     -14400  2020-03-30 16:02:00  8.01      2.75
# 1     -14400  2020-03-30 16:02:00  0.00  49828.45
# 2     -14400  2020-03-30 16:02:00  5.49      8.04
# 3     -14400  2020-03-30 16:02:00  8.72     10.72
# 4     -14400  2020-03-30 16:02:00  7.39      4.05
#
# [5 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #2:
# Set #2:    'AXP,MS,BLK,USB,GS'
# Set #3:    'TFC,CB,SPGI,PNC,SCHW'
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #2: 'symbol': 'AXP,MS,BLK,USB,GS',
params = {'symbol': 'AXP,MS,BLK,USB,GS',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'AXP',
#    'name': 'American Express Company',
#    'currency': 'USD',
#    'price': '90.27',
#    'price_open': '88.51',
#    'day_high': '91.39',
#    'day_low': '85.27',
#    '52_week_high': '138.13',
#    '52_week_low': '67.00',
#    'day_change': '1.54',
#    'change_pct': '1.74',
#    'close_yesterday': '88.73',
#    'market_cap': '72737579008',
#    'volume': '5221244',
#    'volume_avg': '9869300',
#    'shares': '805777984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '11.30',
#    'eps': '7.99'},
#   {'symbol': 'BLK',
#    'name': 'BlackRock, Inc.',
#    'currency': 'USD',
#    'price': '455.35',
#    'price_open': '438.00',
#    'day_high': '456.25',
#    'day_low': '434.51',
#    '52_week_high': '576.81',
#    '52_week_low': '323.98',
#    'day_change': '21.01',
#    'change_pct': '4.84',
#    'close_yesterday': '434.34',
#    'market_cap': '70940794880',
#    'volume': '1109987',
#    'volume_avg': '1449816',
#    'shares': '154828000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '16.02',
#    'eps': '28.43'},
#   {'symbol': 'GS',
#    'name': 'The Goldman Sachs Group, Inc.',
#    'currency': 'USD',
#    'price': '159.62',
#    'price_open': '159.08',
#    'day_high': '160.43',
#    'day_low': '153.18',
#    '52_week_high': '250.46',
#    '52_week_low': '130.85',
#    'day_change': '1.28',
#    'change_pct': '0.81',
#    'close_yesterday': '158.34',
#    'market_cap': '54889164800',
#    'volume': '4135950',
#    'volume_avg': '6536233',
#    'shares': '343873984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '7.59',
#    'eps': '21.03'},
#   {'symbol': 'MS',
#    'name': 'Morgan Stanley',
#    'currency': 'USD',
#    'price': '34.84',
#    'price_open': '33.53',
#    'day_high': '35.34',
#    'day_low': '32.97',
#    '52_week_high': '57.57',
#    '52_week_low': '27.20',
#    'day_change': '0.83',
#    'change_pct': '2.44',
#    'close_yesterday': '34.01',
#    'market_cap': '53388816384',
#    'volume': '17474730',
#    'volume_avg': '27794983',
#    'shares': '1532400000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '6.71',
#    'eps': '5.19'},
#   {'symbol': 'USB',
#    'name': 'U.S. Bancorp',
#    'currency': 'USD',
#    'price': '35.87',
#    'price_open': '35.00',
#    'day_high': '36.10',
#    'day_low': '34.01',
#    '52_week_high': '61.11',
#    '52_week_low': '28.59',
#    'day_change': '0.52',
#    'change_pct': '1.47',
#    'close_yesterday': '35.35',
#    'market_cap': '54567596032',
#    'volume': '9607888',
#    'volume_avg': '15508000',
#    'shares': '1521260032',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '8.62',
#    'eps': '4.16'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__AXP_MS_BLK_USB_GS__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_two = ['AXP', 'MS', 'BLK', 'USB', 'GS']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_two:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_two_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_two_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_two_df" DataFrame columns:
stocks_response_json_list_two_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_two_df
# Out:
#   symbol                           name currency   price price_open day_high  \
# 0    AXP       American Express Company      USD   90.27      88.51    91.39
# 1    BLK                BlackRock, Inc.      USD  455.35     438.00   456.25
# 2     GS  The Goldman Sachs Group, Inc.      USD  159.62     159.08   160.43
# 3     MS                 Morgan Stanley      USD   34.84      33.53    35.34
# 4    USB                   U.S. Bancorp      USD   35.87      35.00    36.10
#
#   day_low 52_week_high 52_week_low day_change  ... volume_avg      shares  \
# 0   85.27       138.13       67.00       1.54  ...    9869300   805777984
# 1  434.51       576.81      323.98      21.01  ...    1449816   154828000
# 2  153.18       250.46      130.85       1.28  ...    6536233   343873984
# 3   32.97        57.57       27.20       0.83  ...   27794983  1532400000
# 4   34.01        61.11       28.59       0.52  ...   15508000  1521260032
#
#        stock_exchange_long stock_exchange_short timezone     timezone_name  \
# 0  New York Stock Exchange                 NYSE      EDT  America/New_York
# 1  New York Stock Exchange                 NYSE      EDT  America/New_York
# 2  New York Stock Exchange                 NYSE      EDT  America/New_York
# 3  New York Stock Exchange                 NYSE      EDT  America/New_York
# 4  New York Stock Exchange                 NYSE      EDT  America/New_York
#
#   gmt_offset      last_trade_time     pe    eps
# 0     -14400  2020-03-30 16:02:00  11.30   7.99
# 1     -14400  2020-03-30 16:02:00  16.02  28.43
# 2     -14400  2020-03-30 16:02:00   7.59  21.03
# 3     -14400  2020-03-30 16:02:00   6.71   5.19
# 4     -14400  2020-03-30 16:02:00   8.62   4.16
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_two_df" to the end of "stocks_response_json_list_one_df":
appended_one_thru_two_df = stocks_response_json_list_one_df.append(stocks_response_json_list_two_df, ignore_index = True)
appended_one_thru_two_df
# Out:
#   symbol                           name currency   price price_open day_high  \
# 0    BAC    Bank of America Corporation      USD   22.04      21.65    22.35
# 1  BRK.B        Berkshire Hathaway Inc.      USD  183.18     180.04   184.11
# 2      C                 Citigroup Inc.      USD   44.08      44.05    44.26
# 3    JPM           JPMorgan Chase & Co.      USD   93.50      90.65    94.09
# 4    WFC          Wells Fargo & Company      USD   29.92      30.36    30.48
# 5    AXP       American Express Company      USD   90.27      88.51    91.39
# 6    BLK                BlackRock, Inc.      USD  455.35     438.00   456.25
# 7     GS  The Goldman Sachs Group, Inc.      USD  159.62     159.08   160.43
# 8     MS                 Morgan Stanley      USD   34.84      33.53    35.34
# 9    USB                   U.S. Bancorp      USD   35.87      35.00    36.10
#
#   day_low 52_week_high 52_week_low day_change  ... volume_avg      shares  \
# 0   21.27        35.72       17.95       0.44  ...  139202966  8724769792
# 1  178.00       231.61      159.50       3.52  ...   14005383  1382349952
# 2   41.58        83.11       32.00       0.28  ...   33415683  2098210048
# 3   89.30       141.10       76.91       2.37  ...   32501400  3084000000
# 4   28.89        54.75       25.11      -0.36  ...   51229066  4089400064
# 5   85.27       138.13       67.00       1.54  ...    9869300   805777984
# 6  434.51       576.81      323.98      21.01  ...    1449816   154828000
# 7  153.18       250.46      130.85       1.28  ...    6536233   343873984
# 8   32.97        57.57       27.20       0.83  ...   27794983  1532400000
# 9   34.01        61.11       28.59       0.52  ...   15508000  1521260032
#
#        stock_exchange_long stock_exchange_short timezone     timezone_name  \
# 0  New York Stock Exchange                 NYSE      EDT  America/New_York
# 1  New York Stock Exchange                 NYSE      EDT  America/New_York
# 2  New York Stock Exchange                 NYSE      EDT  America/New_York
# 3  New York Stock Exchange                 NYSE      EDT  America/New_York
# 4  New York Stock Exchange                 NYSE      EDT  America/New_York
# 5  New York Stock Exchange                 NYSE      EDT  America/New_York
# 6  New York Stock Exchange                 NYSE      EDT  America/New_York
# 7  New York Stock Exchange                 NYSE      EDT  America/New_York
# 8  New York Stock Exchange                 NYSE      EDT  America/New_York
# 9  New York Stock Exchange                 NYSE      EDT  America/New_York
#
#   gmt_offset      last_trade_time     pe       eps
# 0     -14400  2020-03-30 16:02:00   8.01      2.75
# 1     -14400  2020-03-30 16:02:00   0.00  49828.45
# 2     -14400  2020-03-30 16:02:00   5.49      8.04
# 3     -14400  2020-03-30 16:02:00   8.72     10.72
# 4     -14400  2020-03-30 16:02:00   7.39      4.05
# 5     -14400  2020-03-30 16:02:00  11.30      7.99
# 6     -14400  2020-03-30 16:02:00  16.02     28.43
# 7     -14400  2020-03-30 16:02:00   7.59     21.03
# 8     -14400  2020-03-30 16:02:00   6.71      5.19
# 9     -14400  2020-03-30 16:02:00   8.62      4.16
#
# [10 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #3:
# Set #3:    'TFC,CB,SPGI,PNC,SCHW'
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #3: 'symbol': 'TFC,CB,SPGI,PNC,SCHW',
params = {'symbol': 'TFC,CB,SPGI,PNC,SCHW',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'CB',
#    'name': 'Chubb Limited',
#    'currency': 'USD',
#    'price': '114.04',
#    'price_open': '108.64',
#    'day_high': '114.71',
#    'day_low': '105.63',
#    '52_week_high': '167.74',
#    '52_week_low': '87.35',
#    'day_change': '5.63',
#    'change_pct': '5.19',
#    'close_yesterday': '108.41',
#    'market_cap': '51535589376',
#    'volume': '2678682',
#    'volume_avg': '4048716',
#    'shares': '451972000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '11.74',
#    'eps': '9.71'},
#   {'symbol': 'PNC',
#    'name': 'The PNC Financial Services Group, Inc.',
#    'currency': 'USD',
#    'price': '100.97',
#    'price_open': '99.27',
#    'day_high': '101.68',
#    'day_low': '97.82',
#    '52_week_high': '161.79',
#    '52_week_low': '79.41',
#    'day_change': '0.84',
#    'change_pct': '0.84',
#    'close_yesterday': '100.13',
#    'market_cap': '43288567808',
#    'volume': '2609286',
#    'volume_avg': '3831633',
#    'shares': '428727008',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '8.87',
#    'eps': '11.38'},
#   {'symbol': 'SCHW',
#    'name': 'The Charles Schwab Corporation',
#    'currency': 'USD',
#    'price': '34.33',
#    'price_open': '33.19',
#    'day_high': '34.57',
#    'day_low': '32.69',
#    '52_week_high': '51.65',
#    '52_week_low': '28.00',
#    'day_change': '0.72',
#    'change_pct': '2.14',
#    'close_yesterday': '33.61',
#    'market_cap': '44155936768',
#    'volume': '9841397',
#    'volume_avg': '17767516',
#    'shares': '1286220032',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '12.86',
#    'eps': '2.67'},
#   {'symbol': 'SPGI',
#    'name': 'S&P Global Inc.',
#    'currency': 'USD',
#    'price': '246.99',
#    'price_open': '241.41',
#    'day_high': '248.63',
#    'day_low': '239.01',
#    '52_week_high': '312.94',
#    '52_week_low': '186.06',
#    'day_change': '7.24',
#    'change_pct': '3.02',
#    'close_yesterday': '239.75',
#    'market_cap': '60216164352',
#    'volume': '2465668',
#    'volume_avg': '2795633',
#    'shares': '244000000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '28.72',
#    'eps': '8.60'},
#   {'symbol': 'TFC',
#    'name': 'Truist Financial Corporation',
#    'currency': 'USD',
#    'price': '32.56',
#    'price_open': '32.49',
#    'day_high': '33.53',
#    'day_low': '31.68',
#    '52_week_high': '56.92',
#    '52_week_low': '24.01',
#    'day_change': '-0.71',
#    'change_pct': '-2.13',
#    'close_yesterday': '33.27',
#    'market_cap': '43793199104',
#    'volume': '7708654',
#    'volume_avg': '11851916',
#    'shares': '1344999936',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': 'N/A',
#    'eps': 'N/A'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__TFC_CB_SPGI_PNC_SCHW__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_three = ['TFC', 'CB', 'SPGI', 'PNC', 'SCHW']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_three:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_three_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_three_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_three_df" DataFrame columns:
stocks_response_json_list_three_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_three_df
# Out:
#   symbol                                    name currency   price price_open  \
# 0     CB                           Chubb Limited      USD  114.04     108.64
# 1    PNC  The PNC Financial Services Group, Inc.      USD  100.97      99.27
# 2   SCHW          The Charles Schwab Corporation      USD   34.33      33.19
# 3   SPGI                         S&P Global Inc.      USD  246.99     241.41
# 4    TFC            Truist Financial Corporation      USD   32.56      32.49
#
#   day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0   114.71  105.63       167.74       87.35       5.63  ...    4048716
# 1   101.68   97.82       161.79       79.41       0.84  ...    3831633
# 2    34.57   32.69        51.65       28.00       0.72  ...   17767516
# 3   248.63  239.01       312.94      186.06       7.24  ...    2795633
# 4    33.53   31.68        56.92       24.01      -0.71  ...   11851916
#
#        shares      stock_exchange_long stock_exchange_short timezone  \
# 0   451972000  New York Stock Exchange                 NYSE      EDT
# 1   428727008  New York Stock Exchange                 NYSE      EDT
# 2  1286220032  New York Stock Exchange                 NYSE      EDT
# 3   244000000  New York Stock Exchange                 NYSE      EDT
# 4  1344999936  New York Stock Exchange                 NYSE      EDT
#
#       timezone_name gmt_offset      last_trade_time     pe    eps
# 0  America/New_York     -14400  2020-03-30 16:02:00  11.74   9.71
# 1  America/New_York     -14400  2020-03-30 16:02:00   8.87  11.38
# 2  America/New_York     -14400  2020-03-30 16:02:00  12.86   2.67
# 3  America/New_York     -14400  2020-03-30 16:02:00  28.72   8.60
# 4  America/New_York     -14400  2020-03-30 16:02:00    N/A    N/A
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_three_df" to the end of "appended_one_thru_two_df":
appended_one_thru_three_df = appended_one_thru_two_df.append(stocks_response_json_list_three_df, ignore_index = True)
appended_one_thru_three_df
# Out:
#    symbol                                    name currency   price price_open  \
# 0     BAC             Bank of America Corporation      USD   22.04      21.65
# 1   BRK.B                 Berkshire Hathaway Inc.      USD  183.18     180.04
# 2       C                          Citigroup Inc.      USD   44.08      44.05
# 3     JPM                    JPMorgan Chase & Co.      USD   93.50      90.65
# 4     WFC                   Wells Fargo & Company      USD   29.92      30.36
# 5     AXP                American Express Company      USD   90.27      88.51
# 6     BLK                         BlackRock, Inc.      USD  455.35     438.00
# 7      GS           The Goldman Sachs Group, Inc.      USD  159.62     159.08
# 8      MS                          Morgan Stanley      USD   34.84      33.53
# 9     USB                            U.S. Bancorp      USD   35.87      35.00
# 10     CB                           Chubb Limited      USD  114.04     108.64
# 11    PNC  The PNC Financial Services Group, Inc.      USD  100.97      99.27
# 12   SCHW          The Charles Schwab Corporation      USD   34.33      33.19
# 13   SPGI                         S&P Global Inc.      USD  246.99     241.41
# 14    TFC            Truist Financial Corporation      USD   32.56      32.49
#
#    day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0     22.35   21.27        35.72       17.95       0.44  ...  139202966
# 1    184.11  178.00       231.61      159.50       3.52  ...   14005383
# 2     44.26   41.58        83.11       32.00       0.28  ...   33415683
# 3     94.09   89.30       141.10       76.91       2.37  ...   32501400
# 4     30.48   28.89        54.75       25.11      -0.36  ...   51229066
# 5     91.39   85.27       138.13       67.00       1.54  ...    9869300
# 6    456.25  434.51       576.81      323.98      21.01  ...    1449816
# 7    160.43  153.18       250.46      130.85       1.28  ...    6536233
# 8     35.34   32.97        57.57       27.20       0.83  ...   27794983
# 9     36.10   34.01        61.11       28.59       0.52  ...   15508000
# 10   114.71  105.63       167.74       87.35       5.63  ...    4048716
# 11   101.68   97.82       161.79       79.41       0.84  ...    3831633
# 12    34.57   32.69        51.65       28.00       0.72  ...   17767516
# 13   248.63  239.01       312.94      186.06       7.24  ...    2795633
# 14    33.53   31.68        56.92       24.01      -0.71  ...   11851916
#
#         shares      stock_exchange_long stock_exchange_short timezone  \
# 0   8724769792  New York Stock Exchange                 NYSE      EDT
# 1   1382349952  New York Stock Exchange                 NYSE      EDT
# 2   2098210048  New York Stock Exchange                 NYSE      EDT
# 3   3084000000  New York Stock Exchange                 NYSE      EDT
# 4   4089400064  New York Stock Exchange                 NYSE      EDT
# 5    805777984  New York Stock Exchange                 NYSE      EDT
# 6    154828000  New York Stock Exchange                 NYSE      EDT
# 7    343873984  New York Stock Exchange                 NYSE      EDT
# 8   1532400000  New York Stock Exchange                 NYSE      EDT
# 9   1521260032  New York Stock Exchange                 NYSE      EDT
# 10   451972000  New York Stock Exchange                 NYSE      EDT
# 11   428727008  New York Stock Exchange                 NYSE      EDT
# 12  1286220032  New York Stock Exchange                 NYSE      EDT
# 13   244000000  New York Stock Exchange                 NYSE      EDT
# 14  1344999936  New York Stock Exchange                 NYSE      EDT
#
#        timezone_name gmt_offset      last_trade_time     pe       eps
# 0   America/New_York     -14400  2020-03-30 16:02:00   8.01      2.75
# 1   America/New_York     -14400  2020-03-30 16:02:00   0.00  49828.45
# 2   America/New_York     -14400  2020-03-30 16:02:00   5.49      8.04
# 3   America/New_York     -14400  2020-03-30 16:02:00   8.72     10.72
# 4   America/New_York     -14400  2020-03-30 16:02:00   7.39      4.05
# 5   America/New_York     -14400  2020-03-30 16:02:00  11.30      7.99
# 6   America/New_York     -14400  2020-03-30 16:02:00  16.02     28.43
# 7   America/New_York     -14400  2020-03-30 16:02:00   7.59     21.03
# 8   America/New_York     -14400  2020-03-30 16:02:00   6.71      5.19
# 9   America/New_York     -14400  2020-03-30 16:02:00   8.62      4.16
# 10  America/New_York     -14400  2020-03-30 16:02:00  11.74      9.71
# 11  America/New_York     -14400  2020-03-30 16:02:00   8.87     11.38
# 12  America/New_York     -14400  2020-03-30 16:02:00  12.86      2.67
# 13  America/New_York     -14400  2020-03-30 16:02:00  28.72      8.60
# 14  America/New_York     -14400  2020-03-30 16:02:00    N/A       N/A
#
# [15 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #4:
# Set #4:    'MMC,AON,ICE,MCO,PGR'
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #4: 'symbol': 'MMC,AON,ICE,MCO,PGR',
params = {'symbol': 'MMC,AON,ICE,MCO,PGR',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'AON',
#    'name': 'Aon plc',
#    'currency': 'USD',
#    'price': '171.03',
#    'price_open': '167.58',
#    'day_high': '173.01',
#    'day_low': '162.11',
#    '52_week_high': '238.19',
#    '52_week_low': '143.93',
#    'day_change': '5.61',
#    'change_pct': '3.39',
#    'close_yesterday': '165.42',
#    'market_cap': '39561289728',
#    'volume': '1706749',
#    'volume_avg': '2684533',
#    'shares': '231312000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '26.87',
#    'eps': '6.37'},
#   {'symbol': 'ICE',
#    'name': 'Intercontinental Exchange, Inc.',
#    'currency': 'USD',
#    'price': '83.81',
#    'price_open': '77.66',
#    'day_high': '84.50',
#    'day_low': '81.30',
#    '52_week_high': '101.93',
#    '52_week_low': '63.51',
#    'day_change': '2.56',
#    'change_pct': '3.15',
#    'close_yesterday': '81.25',
#    'market_cap': '46023254016',
#    'volume': '4597747',
#    'volume_avg': '5706783',
#    'shares': '549137984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '24.51',
#    'eps': '3.42'},
#   {'symbol': 'MCO',
#    'name': "Moody's Corporation",
#    'currency': 'USD',
#    'price': '222.22',
#    'price_open': '222.16',
#    'day_high': '226.33',
#    'day_low': '218.30',
#    '52_week_high': '287.25',
#    '52_week_low': '164.19',
#    'day_change': '2.03',
#    'change_pct': '0.92',
#    'close_yesterday': '220.19',
#    'market_cap': '41601363968',
#    'volume': '1000539',
#    'volume_avg': '1627516',
#    'shares': '187208000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '29.95',
#    'eps': '7.42'},
#   {'symbol': 'MMC',
#    'name': 'Marsh & McLennan Companies, Inc.',
#    'currency': 'USD',
#    'price': '89.55',
#    'price_open': '82.74',
#    'day_high': '89.90',
#    'day_low': '84.99',
#    '52_week_high': '119.88',
#    '52_week_low': '74.33',
#    'day_change': '4.10',
#    'change_pct': '4.80',
#    'close_yesterday': '85.45',
#    'market_cap': '45124067328',
#    'volume': '2682072',
#    'volume_avg': '3776716',
#    'shares': '503897984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '26.26',
#    'eps': '3.41'},
#   {'symbol': 'PGR',
#    'name': 'The Progressive Corporation',
#    'currency': 'USD',
#    'price': '76.18',
#    'price_open': '74.17',
#    'day_high': '76.83',
#    'day_low': '73.12',
#    '52_week_high': '84.96',
#    '52_week_low': '62.18',
#    'day_change': '2.64',
#    'change_pct': '3.59',
#    'close_yesterday': '73.54',
#    'market_cap': '44584652800',
#    'volume': '3854164',
#    'volume_avg': '5436133',
#    'shares': '584600000',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '11.34',
#    'eps': '6.72'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__MMC_AON_ICE_MCO_PGR__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_four = ['MMC', 'AON', 'ICE', 'MCO', 'PGR']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_four:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_four_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_four_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_four_df" DataFrame columns:
stocks_response_json_list_four_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_four_df
# Out:
#   symbol                              name currency   price price_open  \
# 0    AON                           Aon plc      USD  171.03     167.58
# 1    ICE   Intercontinental Exchange, Inc.      USD   83.81      77.66
# 2    MCO               Moody's Corporation      USD  222.22     222.16
# 3    MMC  Marsh & McLennan Companies, Inc.      USD   89.55      82.74
# 4    PGR       The Progressive Corporation      USD   76.18      74.17
#
#   day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0   173.01  162.11       238.19      143.93       5.61  ...    2684533
# 1    84.50   81.30       101.93       63.51       2.56  ...    5706783
# 2   226.33  218.30       287.25      164.19       2.03  ...    1627516
# 3    89.90   84.99       119.88       74.33       4.10  ...    3776716
# 4    76.83   73.12        84.96       62.18       2.64  ...    5436133
#
#       shares      stock_exchange_long stock_exchange_short timezone  \
# 0  231312000  New York Stock Exchange                 NYSE      EDT
# 1  549137984  New York Stock Exchange                 NYSE      EDT
# 2  187208000  New York Stock Exchange                 NYSE      EDT
# 3  503897984  New York Stock Exchange                 NYSE      EDT
# 4  584600000  New York Stock Exchange                 NYSE      EDT
#
#       timezone_name gmt_offset      last_trade_time     pe   eps
# 0  America/New_York     -14400  2020-03-30 16:02:00  26.87  6.37
# 1  America/New_York     -14400  2020-03-30 16:02:00  24.51  3.42
# 2  America/New_York     -14400  2020-03-30 16:02:00  29.95  7.42
# 3  America/New_York     -14400  2020-03-30 16:02:00  26.26  3.41
# 4  America/New_York     -14400  2020-03-30 16:02:00  11.34  6.72
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_four_df" to the end of "appended_one_thru_three_df":
appended_one_thru_four_df = appended_one_thru_three_df.append(stocks_response_json_list_four_df, ignore_index = True)
appended_one_thru_four_df
# Out:
#    symbol                                    name currency   price price_open  \
# 0     BAC             Bank of America Corporation      USD   22.04      21.65
# 1   BRK.B                 Berkshire Hathaway Inc.      USD  183.18     180.04
# 2       C                          Citigroup Inc.      USD   44.08      44.05
# 3     JPM                    JPMorgan Chase & Co.      USD   93.50      90.65
# 4     WFC                   Wells Fargo & Company      USD   29.92      30.36
# 5     AXP                American Express Company      USD   90.27      88.51
# 6     BLK                         BlackRock, Inc.      USD  455.35     438.00
# 7      GS           The Goldman Sachs Group, Inc.      USD  159.62     159.08
# 8      MS                          Morgan Stanley      USD   34.84      33.53
# 9     USB                            U.S. Bancorp      USD   35.87      35.00
# 10     CB                           Chubb Limited      USD  114.04     108.64
# 11    PNC  The PNC Financial Services Group, Inc.      USD  100.97      99.27
# 12   SCHW          The Charles Schwab Corporation      USD   34.33      33.19
# 13   SPGI                         S&P Global Inc.      USD  246.99     241.41
# 14    TFC            Truist Financial Corporation      USD   32.56      32.49
# 15    AON                                 Aon plc      USD  171.03     167.58
# 16    ICE         Intercontinental Exchange, Inc.      USD   83.81      77.66
# 17    MCO                     Moody's Corporation      USD  222.22     222.16
# 18    MMC        Marsh & McLennan Companies, Inc.      USD   89.55      82.74
# 19    PGR             The Progressive Corporation      USD   76.18      74.17
#
#    day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0     22.35   21.27        35.72       17.95       0.44  ...  139202966
# 1    184.11  178.00       231.61      159.50       3.52  ...   14005383
# 2     44.26   41.58        83.11       32.00       0.28  ...   33415683
# 3     94.09   89.30       141.10       76.91       2.37  ...   32501400
# 4     30.48   28.89        54.75       25.11      -0.36  ...   51229066
# 5     91.39   85.27       138.13       67.00       1.54  ...    9869300
# 6    456.25  434.51       576.81      323.98      21.01  ...    1449816
# 7    160.43  153.18       250.46      130.85       1.28  ...    6536233
# 8     35.34   32.97        57.57       27.20       0.83  ...   27794983
# 9     36.10   34.01        61.11       28.59       0.52  ...   15508000
# 10   114.71  105.63       167.74       87.35       5.63  ...    4048716
# 11   101.68   97.82       161.79       79.41       0.84  ...    3831633
# 12    34.57   32.69        51.65       28.00       0.72  ...   17767516
# 13   248.63  239.01       312.94      186.06       7.24  ...    2795633
# 14    33.53   31.68        56.92       24.01      -0.71  ...   11851916
# 15   173.01  162.11       238.19      143.93       5.61  ...    2684533
# 16    84.50   81.30       101.93       63.51       2.56  ...    5706783
# 17   226.33  218.30       287.25      164.19       2.03  ...    1627516
# 18    89.90   84.99       119.88       74.33       4.10  ...    3776716
# 19    76.83   73.12        84.96       62.18       2.64  ...    5436133
#
#         shares      stock_exchange_long stock_exchange_short timezone  \
# 0   8724769792  New York Stock Exchange                 NYSE      EDT
# 1   1382349952  New York Stock Exchange                 NYSE      EDT
# 2   2098210048  New York Stock Exchange                 NYSE      EDT
# 3   3084000000  New York Stock Exchange                 NYSE      EDT
# 4   4089400064  New York Stock Exchange                 NYSE      EDT
# 5    805777984  New York Stock Exchange                 NYSE      EDT
# 6    154828000  New York Stock Exchange                 NYSE      EDT
# 7    343873984  New York Stock Exchange                 NYSE      EDT
# 8   1532400000  New York Stock Exchange                 NYSE      EDT
# 9   1521260032  New York Stock Exchange                 NYSE      EDT
# 10   451972000  New York Stock Exchange                 NYSE      EDT
# 11   428727008  New York Stock Exchange                 NYSE      EDT
# 12  1286220032  New York Stock Exchange                 NYSE      EDT
# 13   244000000  New York Stock Exchange                 NYSE      EDT
# 14  1344999936  New York Stock Exchange                 NYSE      EDT
# 15   231312000  New York Stock Exchange                 NYSE      EDT
# 16   549137984  New York Stock Exchange                 NYSE      EDT
# 17   187208000  New York Stock Exchange                 NYSE      EDT
# 18   503897984  New York Stock Exchange                 NYSE      EDT
# 19   584600000  New York Stock Exchange                 NYSE      EDT
#
#        timezone_name gmt_offset      last_trade_time     pe       eps
# 0   America/New_York     -14400  2020-03-30 16:02:00   8.01      2.75
# 1   America/New_York     -14400  2020-03-30 16:02:00   0.00  49828.45
# 2   America/New_York     -14400  2020-03-30 16:02:00   5.49      8.04
# 3   America/New_York     -14400  2020-03-30 16:02:00   8.72     10.72
# 4   America/New_York     -14400  2020-03-30 16:02:00   7.39      4.05
# 5   America/New_York     -14400  2020-03-30 16:02:00  11.30      7.99
# 6   America/New_York     -14400  2020-03-30 16:02:00  16.02     28.43
# 7   America/New_York     -14400  2020-03-30 16:02:00   7.59     21.03
# 8   America/New_York     -14400  2020-03-30 16:02:00   6.71      5.19
# 9   America/New_York     -14400  2020-03-30 16:02:00   8.62      4.16
# 10  America/New_York     -14400  2020-03-30 16:02:00  11.74      9.71
# 11  America/New_York     -14400  2020-03-30 16:02:00   8.87     11.38
# 12  America/New_York     -14400  2020-03-30 16:02:00  12.86      2.67
# 13  America/New_York     -14400  2020-03-30 16:02:00  28.72      8.60
# 14  America/New_York     -14400  2020-03-30 16:02:00    N/A       N/A
# 15  America/New_York     -14400  2020-03-30 16:02:00  26.87      6.37
# 16  America/New_York     -14400  2020-03-30 16:02:00  24.51      3.42
# 17  America/New_York     -14400  2020-03-30 16:02:00  29.95      7.42
# 18  America/New_York     -14400  2020-03-30 16:02:00  26.26      3.41
# 19  America/New_York     -14400  2020-03-30 16:02:00  11.34      6.72
#
# [20 rows x 24 columns]

# %%
# REAL TIME MARKET DATA - SECTION #5:
# Set #5:    'MET,AIG,COF,BK,ALL'

# WTD - API - Real Time Market Data - Request URL:
url = 'https://api.worldtradingdata.com/api/v1/stock'
#'api_token': 'demo'

# WTD - API - Real Time Market Data - API Parameters:
# Set #5: 'symbol': 'MET,AIG,COF,BK,ALL',
params = {'symbol': 'MET,AIG,COF,BK,ALL',
          'api_token': world_trading_data_api_token,
          'output': 'json'}
          
# WTD - API - Real Time Market Data - Send Data Request to API:
stocks_response_api = requests.request('GET', url, params = params)

# %%
# WTD - Real Time Market Data - Convert to JSON dictionary:
# ***NOTE - MUST INCLUDE IN PARAMS***:  'output': 'json'
stocks_response_json = stocks_response_api.json()
stocks_response_json
# Out:
# {'symbols_requested': 5,
#  'symbols_returned': 5,
#  'data': [{'symbol': 'AIG',
#    'name': 'American International Group, Inc.',
#    'currency': 'USD',
#    'price': '25.71',
#    'price_open': '25.00',
#    'day_high': '25.99',
#    'day_low': '24.07',
#    '52_week_high': '58.66',
#    '52_week_low': '16.07',
#    'day_change': '0.20',
#    'change_pct': '0.78',
#    'close_yesterday': '25.51',
#    'market_cap': '22258739200',
#    'volume': '8155372',
#    'volume_avg': '11517800',
#    'shares': '865761984',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '6.87',
#    'eps': '3.74'},
#   {'symbol': 'ALL',
#    'name': 'The Allstate Corporation',
#    'currency': 'USD',
#    'price': '94.64',
#    'price_open': '88.28',
#    'day_high': '95.29',
#    'day_low': '85.48',
#    '52_week_high': '125.92',
#    '52_week_low': '64.13',
#    'day_change': '6.18',
#    'change_pct': '6.99',
#    'close_yesterday': '88.46',
#    'market_cap': '29992738816',
#    'volume': '2714327',
#    'volume_avg': '3342550',
#    'shares': '318791008',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '6.75',
#    'eps': '14.03'},
#   {'symbol': 'BK',
#    'name': 'The Bank of New York Mellon Corporation',
#    'currency': 'USD',
#    'price': '34.00',
#    'price_open': '32.60',
#    'day_high': '34.18',
#    'day_low': '31.72',
#    '52_week_high': '53.61',
#    '52_week_low': '26.40',
#    'day_change': '1.46',
#    'change_pct': '4.49',
#    'close_yesterday': '32.54',
#    'market_cap': '30091735040',
#    'volume': '6103099',
#    'volume_avg': '8599116',
#    'shares': '885051008',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '7.54',
#    'eps': '4.51'},
#   {'symbol': 'COF',
#    'name': 'Capital One Financial Corporation',
#    'currency': 'USD',
#    'price': '53.87',
#    'price_open': '54.62',
#    'day_high': '54.99',
#    'day_low': '52.32',
#    '52_week_high': '107.59',
#    '52_week_low': '38.00',
#    'day_change': '-1.43',
#    'change_pct': '-2.59',
#    'close_yesterday': '55.30',
#    'market_cap': '24625215488',
#    'volume': '3683453',
#    'volume_avg': '6033316',
#    'shares': '465720992',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '4.88',
#    'eps': '11.05'},
#   {'symbol': 'MET',
#    'name': 'MetLife, Inc.',
#    'currency': 'USD',
#    'price': '32.03',
#    'price_open': '30.73',
#    'day_high': '32.30',
#    'day_low': '30.25',
#    '52_week_high': '53.28',
#    '52_week_low': '22.85',
#    'day_change': '1.16',
#    'change_pct': '3.76',
#    'close_yesterday': '30.87',
#    'market_cap': '29333968896',
#    'volume': '6044193',
#    'volume_avg': '12227466',
#    'shares': '915299968',
#    'stock_exchange_long': 'New York Stock Exchange',
#    'stock_exchange_short': 'NYSE',
#    'timezone': 'EDT',
#    'timezone_name': 'America/New_York',
#    'gmt_offset': '-14400',
#    'last_trade_time': '2020-03-30 16:02:00',
#    'pe': '5.29',
#    'eps': '6.06'}]}

# %%
# WTD - Real Time Market Data - Save "JSON OUTPUT" as a JSON file:
# ***NOTE - MUST ENABLE IN PARAMS***:  'output': 'json' to retrieve "JSON formatted" data from the WTD API.
with open('./output_data/WTD_API__MET_AIG_COF_BK_ALL__RealTimeMarketData.json', 'w') as json_file:
  json.dump(stocks_response_json, json_file)

# %%
# Initialize the "stocks_response_json_list" which is to contain data items from the
# JSON Dictionary API Output, "stocks_response_json", and then be transformed into a pandas DataFrame:
stocks_response_json_list = []

# %%
# Append data items from the JSON Dictionary API Output, "stocks_response_json",
# to the "stocks_response_json_list", using a "nested for loop":

# Stock "ticker symbol" list provided to the WTD API:
stocks_list_five = ['MET', 'AIG', 'COF', 'BK', 'ALL']

# Initialize / reset the value of "j" back to 0 (zero):
j = 0

# "For Loop #1" itirates through the list of ticker symbols, "stocks_list_one":
for i in stocks_list_five:
    
    # If an error(s) IS NOT present in reading data from the JSON Dictionary API Output,
    # "stocks_response_json", then:
    if 'error' not in stocks_response_json:
                
        # Append data items from the JSON Dictionary API Output, "stocks_response_json", to the
        # "stocks_response_json_list":
        stocks_response_json_list.append([stocks_response_json["data"][j]["symbol"],
                                         stocks_response_json["data"][j]["name"],
                                         stocks_response_json["data"][j]["currency"],
                                         stocks_response_json["data"][j]["price"],
                                         stocks_response_json["data"][j]["price_open"],
                                         stocks_response_json["data"][j]["day_high"],
                                         stocks_response_json["data"][j]["day_low"],
                                         stocks_response_json["data"][j]["52_week_high"],
                                         stocks_response_json["data"][j]["52_week_low"],
                                         stocks_response_json["data"][j]["day_change"],
                                         stocks_response_json["data"][j]["change_pct"],
                                         stocks_response_json["data"][j]["close_yesterday"],
                                         stocks_response_json["data"][j]["market_cap"],
                                         stocks_response_json["data"][j]["volume"],
                                         stocks_response_json["data"][j]["volume_avg"],
                                         stocks_response_json["data"][j]["shares"],
                                         stocks_response_json["data"][j]["stock_exchange_long"],
                                         stocks_response_json["data"][j]["stock_exchange_short"],
                                         stocks_response_json["data"][j]["timezone"],
                                         stocks_response_json["data"][j]["timezone_name"],
                                         stocks_response_json["data"][j]["gmt_offset"],
                                         stocks_response_json["data"][j]["last_trade_time"],
                                         stocks_response_json["data"][j]["pe"],
                                         stocks_response_json["data"][j]["eps"]])
        
        # Increment the value of "j" by 1 (one):
        j = j + 1

# %%
# Create "stocks_response_json_list_five_df" DataFrame from "stocks_response_json_list":
stocks_response_json_list_five_df = pd.DataFrame(stocks_response_json_list)

# Add Headers to each of the "stocks_response_json_list_five_df" DataFrame columns:
stocks_response_json_list_five_df.columns = ["symbol", "name", "currency", "price", "price_open", "day_high", "day_low",
                                       "52_week_high", "52_week_low", "day_change", "change_pct", "close_yesterday",
                                       "market_cap", "volume", "volume_avg", "shares", "stock_exchange_long",
                                       "stock_exchange_short", "timezone", "timezone_name", "gmt_offset",
                                       "last_trade_time", "pe", "eps"]
stocks_response_json_list_five_df
# Out:
#   symbol                                     name currency  price price_open  \
# 0    AIG       American International Group, Inc.      USD  25.71      25.00
# 1    ALL                 The Allstate Corporation      USD  94.64      88.28
# 2     BK  The Bank of New York Mellon Corporation      USD  34.00      32.60
# 3    COF        Capital One Financial Corporation      USD  53.87      54.62
# 4    MET                            MetLife, Inc.      USD  32.03      30.73
#
#   day_high day_low 52_week_high 52_week_low day_change  ... volume_avg  \
# 0    25.99   24.07        58.66       16.07       0.20  ...   11517800
# 1    95.29   85.48       125.92       64.13       6.18  ...    3342550
# 2    34.18   31.72        53.61       26.40       1.46  ...    8599116
# 3    54.99   52.32       107.59       38.00      -1.43  ...    6033316
# 4    32.30   30.25        53.28       22.85       1.16  ...   12227466
#
#       shares      stock_exchange_long stock_exchange_short timezone  \
# 0  865761984  New York Stock Exchange                 NYSE      EDT
# 1  318791008  New York Stock Exchange                 NYSE      EDT
# 2  885051008  New York Stock Exchange                 NYSE      EDT
# 3  465720992  New York Stock Exchange                 NYSE      EDT
# 4  915299968  New York Stock Exchange                 NYSE      EDT
#
#       timezone_name gmt_offset      last_trade_time    pe    eps
# 0  America/New_York     -14400  2020-03-30 16:02:00  6.87   3.74
# 1  America/New_York     -14400  2020-03-30 16:02:00  6.75  14.03
# 2  America/New_York     -14400  2020-03-30 16:02:00  7.54   4.51
# 3  America/New_York     -14400  2020-03-30 16:02:00  4.88  11.05
# 4  America/New_York     -14400  2020-03-30 16:02:00  5.29   6.06
#
# [5 rows x 24 columns]

# %%
# Append "stocks_response_json_list_five_df" to the end of "appended_one_thru_four_df":
appended_one_thru_five_df = appended_one_thru_four_df.append(stocks_response_json_list_five_df, ignore_index = True)
appended_one_thru_five_df
# Out:
#    symbol                                     name currency   price  \
# 0     BAC              Bank of America Corporation      USD   22.04
# 1   BRK.B                  Berkshire Hathaway Inc.      USD  183.18
# 2       C                           Citigroup Inc.      USD   44.08
# 3     JPM                     JPMorgan Chase & Co.      USD   93.50
# 4     WFC                    Wells Fargo & Company      USD   29.92
# 5     AXP                 American Express Company      USD   90.27
# 6     BLK                          BlackRock, Inc.      USD  455.35
# 7      GS            The Goldman Sachs Group, Inc.      USD  159.62
# 8      MS                           Morgan Stanley      USD   34.84
# 9     USB                             U.S. Bancorp      USD   35.87
# 10     CB                            Chubb Limited      USD  114.04
# 11    PNC   The PNC Financial Services Group, Inc.      USD  100.97
# 12   SCHW           The Charles Schwab Corporation      USD   34.33
# 13   SPGI                          S&P Global Inc.      USD  246.99
# 14    TFC             Truist Financial Corporation      USD   32.56
# 15    AON                                  Aon plc      USD  171.03
# 16    ICE          Intercontinental Exchange, Inc.      USD   83.81
# 17    MCO                      Moody's Corporation      USD  222.22
# 18    MMC         Marsh & McLennan Companies, Inc.      USD   89.55
# 19    PGR              The Progressive Corporation      USD   76.18
# 20    AIG       American International Group, Inc.      USD   25.71
# 21    ALL                 The Allstate Corporation      USD   94.64
# 22     BK  The Bank of New York Mellon Corporation      USD   34.00
# 23    COF        Capital One Financial Corporation      USD   53.87
# 24    MET                            MetLife, Inc.      USD   32.03
#
#    price_open day_high day_low 52_week_high 52_week_low day_change  ...  \
# 0       21.65    22.35   21.27        35.72       17.95       0.44  ...
# 1      180.04   184.11  178.00       231.61      159.50       3.52  ...
# 2       44.05    44.26   41.58        83.11       32.00       0.28  ...
# 3       90.65    94.09   89.30       141.10       76.91       2.37  ...
# 4       30.36    30.48   28.89        54.75       25.11      -0.36  ...
# 5       88.51    91.39   85.27       138.13       67.00       1.54  ...
# 6      438.00   456.25  434.51       576.81      323.98      21.01  ...
# 7      159.08   160.43  153.18       250.46      130.85       1.28  ...
# 8       33.53    35.34   32.97        57.57       27.20       0.83  ...
# 9       35.00    36.10   34.01        61.11       28.59       0.52  ...
# 10     108.64   114.71  105.63       167.74       87.35       5.63  ...
# 11      99.27   101.68   97.82       161.79       79.41       0.84  ...
# 12      33.19    34.57   32.69        51.65       28.00       0.72  ...
# 13     241.41   248.63  239.01       312.94      186.06       7.24  ...
# 14      32.49    33.53   31.68        56.92       24.01      -0.71  ...
# 15     167.58   173.01  162.11       238.19      143.93       5.61  ...
# 16      77.66    84.50   81.30       101.93       63.51       2.56  ...
# 17     222.16   226.33  218.30       287.25      164.19       2.03  ...
# 18      82.74    89.90   84.99       119.88       74.33       4.10  ...
# 19      74.17    76.83   73.12        84.96       62.18       2.64  ...
# 20      25.00    25.99   24.07        58.66       16.07       0.20  ...
# 21      88.28    95.29   85.48       125.92       64.13       6.18  ...
# 22      32.60    34.18   31.72        53.61       26.40       1.46  ...
# 23      54.62    54.99   52.32       107.59       38.00      -1.43  ...
# 24      30.73    32.30   30.25        53.28       22.85       1.16  ...
#
#    volume_avg      shares      stock_exchange_long stock_exchange_short  \
# 0   139202966  8724769792  New York Stock Exchange                 NYSE
# 1    14005383  1382349952  New York Stock Exchange                 NYSE
# 2    33415683  2098210048  New York Stock Exchange                 NYSE
# 3    32501400  3084000000  New York Stock Exchange                 NYSE
# 4    51229066  4089400064  New York Stock Exchange                 NYSE
# 5     9869300   805777984  New York Stock Exchange                 NYSE
# 6     1449816   154828000  New York Stock Exchange                 NYSE
# 7     6536233   343873984  New York Stock Exchange                 NYSE
# 8    27794983  1532400000  New York Stock Exchange                 NYSE
# 9    15508000  1521260032  New York Stock Exchange                 NYSE
# 10    4048716   451972000  New York Stock Exchange                 NYSE
# 11    3831633   428727008  New York Stock Exchange                 NYSE
# 12   17767516  1286220032  New York Stock Exchange                 NYSE
# 13    2795633   244000000  New York Stock Exchange                 NYSE
# 14   11851916  1344999936  New York Stock Exchange                 NYSE
# 15    2684533   231312000  New York Stock Exchange                 NYSE
# 16    5706783   549137984  New York Stock Exchange                 NYSE
# 17    1627516   187208000  New York Stock Exchange                 NYSE
# 18    3776716   503897984  New York Stock Exchange                 NYSE
# 19    5436133   584600000  New York Stock Exchange                 NYSE
# 20   11517800   865761984  New York Stock Exchange                 NYSE
# 21    3342550   318791008  New York Stock Exchange                 NYSE
# 22    8599116   885051008  New York Stock Exchange                 NYSE
# 23    6033316   465720992  New York Stock Exchange                 NYSE
# 24   12227466   915299968  New York Stock Exchange                 NYSE
#
#    timezone     timezone_name gmt_offset      last_trade_time     pe       eps
# 0       EDT  America/New_York     -14400  2020-03-30 16:02:00   8.01      2.75
# 1       EDT  America/New_York     -14400  2020-03-30 16:02:00   0.00  49828.45
# 2       EDT  America/New_York     -14400  2020-03-30 16:02:00   5.49      8.04
# 3       EDT  America/New_York     -14400  2020-03-30 16:02:00   8.72     10.72
# 4       EDT  America/New_York     -14400  2020-03-30 16:02:00   7.39      4.05
# 5       EDT  America/New_York     -14400  2020-03-30 16:02:00  11.30      7.99
# 6       EDT  America/New_York     -14400  2020-03-30 16:02:00  16.02     28.43
# 7       EDT  America/New_York     -14400  2020-03-30 16:02:00   7.59     21.03
# 8       EDT  America/New_York     -14400  2020-03-30 16:02:00   6.71      5.19
# 9       EDT  America/New_York     -14400  2020-03-30 16:02:00   8.62      4.16
# 10      EDT  America/New_York     -14400  2020-03-30 16:02:00  11.74      9.71
# 11      EDT  America/New_York     -14400  2020-03-30 16:02:00   8.87     11.38
# 12      EDT  America/New_York     -14400  2020-03-30 16:02:00  12.86      2.67
# 13      EDT  America/New_York     -14400  2020-03-30 16:02:00  28.72      8.60
# 14      EDT  America/New_York     -14400  2020-03-30 16:02:00    N/A       N/A
# 15      EDT  America/New_York     -14400  2020-03-30 16:02:00  26.87      6.37
# 16      EDT  America/New_York     -14400  2020-03-30 16:02:00  24.51      3.42
# 17      EDT  America/New_York     -14400  2020-03-30 16:02:00  29.95      7.42
# 18      EDT  America/New_York     -14400  2020-03-30 16:02:00  26.26      3.41
# 19      EDT  America/New_York     -14400  2020-03-30 16:02:00  11.34      6.72
# 20      EDT  America/New_York     -14400  2020-03-30 16:02:00   6.87      3.74
# 21      EDT  America/New_York     -14400  2020-03-30 16:02:00   6.75     14.03
# 22      EDT  America/New_York     -14400  2020-03-30 16:02:00   7.54      4.51
# 23      EDT  America/New_York     -14400  2020-03-30 16:02:00   4.88     11.05
# 24      EDT  America/New_York     -14400  2020-03-30 16:02:00   5.29      6.06
#
# [25 rows x 24 columns]

# %%
# Export the "appended_one_thru_five_df" to a CSV file named "WTD_API_FULL_STOCK_LIST_RealTimeMarketData.csv":
output_data_file = "./output_data/WTD_API_FULL_STOCK_LIST_RealTimeMarketData.csv"
appended_one_thru_five_df.to_csv(output_data_file, index = False, header = True)
